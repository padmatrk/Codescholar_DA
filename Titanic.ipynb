# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import statistics as s
# %matplotlib inline

# %%
dat=sb.load_dataset('titanic');
df=pd.DataFrame(dat)
df=df.filter(items=['survived','pclass','sex','age','fare','embarked'])
df.head()
# Out:
#    survived  pclass     sex   age     fare embarked
# 0         0       3    male  22.0   7.2500        S
# 1         1       1  female  38.0  71.2833        C
# 2         1       3  female  26.0   7.9250        S
# 3         1       1  female  35.0  53.1000        S
# 4         0       3    male  35.0   8.0500        S

# %%
df.select_dtypes(include='number').agg(['count','mean','std','min','max'])
# Out:
#          survived      pclass         age        fare
# count  891.000000  891.000000  714.000000  891.000000
# mean     0.383838    2.308642   29.699118   32.204208
# std      0.486592    0.836071   14.526497   49.693429
# min      0.000000    1.000000    0.420000    0.000000
# max      1.000000    3.000000   80.000000  512.329200

# %%
df[['age','fare','embarked']].head()
# Out:
#     age     fare embarked
# 0  22.0   7.2500        S
# 1  38.0  71.2833        C
# 2  26.0   7.9250        S
# 3  35.0  53.1000        S
# 4  35.0   8.0500        S

# %%
pd.unique(df['embarked'])
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
plt.hist(data=df,x="age",color="green")
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <a list of 10 Patch objects>)

# %%
sb.countplot(x='sex',data=df)

# %%
counts_ = [500000, 1800000, 1200000]
cat_ = ["Deaths", "Total Cases", "Cured"]
plt.pie(counts_, labels = cat_);
